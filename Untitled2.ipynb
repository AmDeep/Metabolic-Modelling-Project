# %%
import numpy as np
import scipy as sp
import pandas as pd
import sympy as sy
import webbrowser as wb

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (20.3)
# Collecting pip
#   Using cached pip-20.3.3-py2.py3-none-any.whl (1.5 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 20.3
#     Uninstalling pip-20.3:
#       Successfully uninstalled pip-20.3
# Successfully installed pip-20.3.3

# %%
# !pip install cameo
# Out:
# Collecting cameo
#   Using cached cameo-0.13.0-py2.py3-none-any.whl (13.8 MB)
# Requirement already satisfied: future>=0.15.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from cameo) (0.18.2)
# Requirement already satisfied: scipy>=0.14.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from cameo) (1.4.1)
# Requirement already satisfied: click>=6.7 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from cameo) (7.0)
# Requirement already satisfied: openpyxl>=2.4.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from cameo) (3.0.3)
# Requirement already satisfied: numexpr>=2.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from cameo) (2.7.1)
# Requirement already satisfied: lazy-object-proxy>=1.2.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from cameo) (1.4.3)
# Requirement already satisfied: networkx>=2.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from cameo) (2.4)
# Requirement already satisfied: requests>=2.10.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from cameo) (2.25.0)
# Requirement already satisfied: numpy>=1.9.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from cameo) (1.19.4)
# Collecting gnomic==1.0.1
#   Using cached gnomic-1.0.1-py3-none-any.whl
# Requirement already satisfied: six>=1.8.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from gnomic==1.0.1->cameo) (1.15.0)
# Collecting grako==3.18.1
#   Using cached grako-3.18.1-py2.py3-none-any.whl (76 kB)
# Collecting optlang==1.4.2
#   Using cached optlang-1.4.2-py2.py3-none-any.whl (121 kB)
# Requirement already satisfied: swiglpk>=1.4.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from optlang==1.4.2->cameo) (4.65.1)
# Requirement already satisfied: sympy>=1.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from optlang==1.4.2->cameo) (1.5.1)
# Collecting blessings>=1.5.1
#   Using cached blessings-1.7-py3-none-any.whl (18 kB)
# Collecting cobra>=0.11.1
#   Using cached cobra-0.20.0-py2.py3-none-any.whl (2.4 MB)
# Collecting python-libsbml-experimental==5.18.3
#   Using cached python_libsbml_experimental-5.18.3-cp36-cp36m-manylinux1_x86_64.whl (7.6 MB)
# Collecting appdirs~=1.4
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting diskcache~=5.0
#   Using cached diskcache-5.1.0-py3-none-any.whl (44 kB)
# Collecting escher>=1.1.2
#   Using cached Escher-1.7.3-py3-none-any.whl (1.2 MB)
# Requirement already satisfied: ipywidgets<8,>=7.4.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from escher>=1.1.2->cameo) (7.5.1)
# Requirement already satisfied: Jinja2<3,>=2.7.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from escher>=1.1.2->cameo) (2.11.1)
# Requirement already satisfied: jsonschema<4,>=3.0.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from escher>=1.1.2->cameo) (3.2.0)
# Collecting httpx~=0.14
#   Using cached httpx-0.16.1-py3-none-any.whl (65 kB)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from httpx~=0.14->cobra>=0.11.1->cameo) (2020.11.8)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from httpx~=0.14->cobra>=0.11.1->cameo) (1.4.0)
# Requirement already satisfied: httpcore==0.12.* in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from httpx~=0.14->cobra>=0.11.1->cameo) (0.12.2)
# Requirement already satisfied: sniffio in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from httpx~=0.14->cobra>=0.11.1->cameo) (1.2.0)
# Requirement already satisfied: h11==0.* in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from httpcore==0.12.*->httpx~=0.14->cobra>=0.11.1->cameo) (0.11.0)
# Requirement already satisfied: contextvars>=2.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sniffio->httpx~=0.14->cobra>=0.11.1->cameo) (2.4)
# Requirement already satisfied: immutables>=0.9 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from contextvars>=2.1->sniffio->httpx~=0.14->cobra>=0.11.1->cameo) (0.14)
# Collecting inspyred>=1.0
#   Using cached inspyred-1.0.1-py2.py3-none-any.whl (88 kB)
# Collecting IProgress>=0.4
#   Using cached IProgress-0.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (5.1.4)
# Requirement already satisfied: traitlets>=4.3.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (4.3.3)
# Requirement already satisfied: ipython>=4.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (7.12.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (5.0.4)
# Requirement already satisfied: tornado>=4.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (6.0.3)
# Requirement already satisfied: jupyter-client in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (5.3.4)
# Requirement already satisfied: pexpect in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (4.8.0)
# Requirement already satisfied: pygments in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (2.7.3)
# Requirement already satisfied: backcall in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.1.0)
# Requirement already satisfied: decorator in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (4.4.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (3.0.3)
# Requirement already satisfied: setuptools>=18.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (45.2.0.post20200210)
# Requirement already satisfied: jedi>=0.10 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.14.1)
# Requirement already satisfied: pickleshare in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.7.5)
# Requirement already satisfied: parso>=0.5.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.5.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from Jinja2<3,>=2.7.3->escher>=1.1.2->cameo) (1.1.1)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from jsonschema<4,>=3.0.1->escher>=1.1.2->cameo) (3.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from jsonschema<4,>=3.0.1->escher>=1.1.2->cameo) (0.15.7)
# Requirement already satisfied: attrs>=17.4.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from jsonschema<4,>=3.0.1->escher>=1.1.2->cameo) (20.3.0)
# Requirement already satisfied: jupyter-core in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (4.6.1)
# Requirement already satisfied: ipython-genutils in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.2.0)
# Requirement already satisfied: et-xmlfile in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from openpyxl>=2.4.5->cameo) (1.0.1)
# Requirement already satisfied: jdcal in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from openpyxl>=2.4.5->cameo) (1.4.1)
# Collecting ordered-set>=1.2
#   Using cached ordered_set-4.0.2-py2.py3-none-any.whl
# Collecting palettable>=2.1.1
#   Using cached palettable-3.3.0-py2.py3-none-any.whl (111 kB)
# Collecting pandas>=1.1.3
#   Using cached pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pandas>=1.1.3->cameo) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pandas>=1.1.3->cameo) (2019.3)
# Requirement already satisfied: wcwidth in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.1.8)
# Collecting pydantic~=1.6
#   Using cached pydantic-1.7.3-cp36-cp36m-manylinux2014_x86_64.whl (9.2 MB)
# Requirement already satisfied: dataclasses>=0.6 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pydantic~=1.6->cobra>=0.11.1->cameo) (0.7)
# Collecting pytest<5,>=4.0.1
#   Using cached pytest-4.6.11-py2.py3-none-any.whl (231 kB)
# Requirement already satisfied: atomicwrites>=1.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pytest<5,>=4.0.1->escher>=1.1.2->cameo) (1.3.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pytest<5,>=4.0.1->escher>=1.1.2->cameo) (8.2.0)
# Requirement already satisfied: py>=1.5.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pytest<5,>=4.0.1->escher>=1.1.2->cameo) (1.8.1)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pytest<5,>=4.0.1->escher>=1.1.2->cameo) (0.13.1)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pytest<5,>=4.0.1->escher>=1.1.2->cameo) (20.7)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from importlib-metadata->jsonschema<4,>=3.0.1->escher>=1.1.2->cameo) (3.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests>=2.10.0->cameo) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests>=2.10.0->cameo) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from requests>=2.10.0->cameo) (1.25.11)
# Collecting rich~=6.0
#   Using cached rich-6.2.0-py3-none-any.whl (150 kB)
# Requirement already satisfied: typing-extensions<4.0.0,>=3.7.4 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from rich~=6.0->cobra>=0.11.1->cameo) (3.7.4.3)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from rich~=6.0->cobra>=0.11.1->cameo) (0.4.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from rich~=6.0->cobra>=0.11.1->cameo) (0.9.1)
# Collecting ruamel.yaml~=0.16
#   Using cached ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from ruamel.yaml~=0.16->cobra>=0.11.1->cameo) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from sympy>=1.0.0->optlang==1.4.2->cameo) (1.1.0)
# Requirement already satisfied: notebook>=4.4.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (6.0.3)
# Requirement already satisfied: pyzmq>=17 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (18.1.1)
# Requirement already satisfied: terminado>=0.8.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.8.3)
# Requirement already satisfied: prometheus-client in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.7.1)
# Requirement already satisfied: nbconvert in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (5.6.1)
# Requirement already satisfied: Send2Trash in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (1.5.0)
# Collecting depinfo
#   Using cached depinfo-1.6.0-py2.py3-none-any.whl (8.6 kB)
# Collecting importlib-resources
#   Using cached importlib_resources-3.3.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.8.4)
# Requirement already satisfied: testpath in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.4.4)
# Requirement already satisfied: defusedxml in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.6.0)
# Requirement already satisfied: bleach in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (3.2.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (1.4.2)
# Requirement already satisfied: webencodings in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from packaging->pytest<5,>=4.0.1->escher>=1.1.2->cameo) (2.4.7)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages (from pexpect->ipython>=4.0.0->ipywidgets<8,>=7.4.0->escher>=1.1.2->cameo) (0.6.0)
# Installing collected packages: ruamel.yaml, rich, python-libsbml-experimental, pydantic, pandas, optlang, importlib-resources, httpx, diskcache, depinfo, appdirs, pytest, grako, cobra, palettable, ordered-set, IProgress, inspyred, gnomic, escher, blessings, cameo
#   Attempting uninstall: ruamel.yaml
#     Found existing installation: ruamel-yaml 0.15.87
# ERROR: Cannot uninstall 'ruamel-yaml'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
# !pip install --ignore-installed ruamel-yaml
# Out:
# Collecting ruamel-yaml
#   Using cached ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Using cached ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Installing collected packages: ruamel.yaml.clib, ruamel-yaml
# Successfully installed ruamel-yaml-0.15.87 ruamel.yaml.clib-0.2.2
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install cobra --ignore-installed ruamel-yaml
# Out:
# Collecting cobra
#   Using cached cobra-0.20.0-py2.py3-none-any.whl (2.4 MB)
# Collecting ruamel-yaml
#   Using cached ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting appdirs~=1.4
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting depinfo
#   Using cached depinfo-1.6.0-py2.py3-none-any.whl (8.6 kB)
# Collecting diskcache~=5.0
#   Using cached diskcache-5.1.0-py3-none-any.whl (44 kB)
# Collecting future
#   Using cached future-0.18.2-py3-none-any.whl
# Collecting httpx~=0.14
#   Using cached httpx-0.16.1-py3-none-any.whl (65 kB)
# Collecting certifi
#   Using cached certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
# Collecting httpcore==0.12.*
#   Using cached httpcore-0.12.2-py3-none-any.whl (54 kB)
# Collecting h11==0.*
#   Using cached h11-0.11.0-py2.py3-none-any.whl (54 kB)
# Collecting importlib-metadata
#   Using cached importlib_metadata-3.3.0-py3-none-any.whl (10 kB)
# Collecting importlib-resources
#   Using cached importlib_resources-3.3.0-py2.py3-none-any.whl (26 kB)
# Collecting numpy~=1.13
#   Using cached numpy-1.19.4-cp36-cp36m-manylinux2010_x86_64.whl (14.5 MB)
# Collecting optlang<1.4.6
#   Using cached optlang-1.4.4-py2.py3-none-any.whl (125 kB)
# Collecting pandas~=1.0
#   Using cached pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting pydantic~=1.6
#   Using cached pydantic-1.7.3-cp36-cp36m-manylinux2014_x86_64.whl (9.2 MB)
# Collecting dataclasses>=0.6
#   Using cached dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting python-dateutil>=2.7.3
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting python-libsbml-experimental==5.18.3
#   Using cached python_libsbml_experimental-5.18.3-cp36-cp36m-manylinux1_x86_64.whl (7.6 MB)
# Collecting pytz>=2017.2
#   Using cached pytz-2020.4-py2.py3-none-any.whl (509 kB)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Using cached rfc3986-1.4.0-py2.py3-none-any.whl (31 kB)
# Collecting idna
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting rich~=6.0
#   Using cached rich-6.2.0-py3-none-any.whl (150 kB)
# Collecting colorama<0.5.0,>=0.4.0
#   Using cached colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting commonmark<0.10.0,>=0.9.0
#   Using cached commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Collecting dataclasses>=0.6
#   Using cached dataclasses-0.7-py3-none-any.whl (18 kB)
# Collecting pygments<3.0.0,>=2.6.0
#   Using cached Pygments-2.7.3-py3-none-any.whl (950 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Using cached ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting six
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting sniffio
#   Using cached sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting contextvars>=2.1
#   Using cached contextvars-2.4-py3-none-any.whl
# Collecting immutables>=0.9
#   Using cached immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98 kB)
# Collecting swiglpk
#   Using cached swiglpk-4.65.1-cp36-cp36m-manylinux1_x86_64.whl (627 kB)
# Collecting sympy>=1.0.0
#   Using cached sympy-1.7.1-py3-none-any.whl (5.9 MB)
# Collecting mpmath>=0.19
#   Using cached mpmath-1.1.0-py3-none-any.whl
# Collecting typing-extensions>=3.6.4
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Installing collected packages: immutables, contextvars, zipp, typing-extensions, sniffio, six, rfc3986, mpmath, idna, h11, sympy, swiglpk, ruamel.yaml.clib, pytz, python-dateutil, pygments, numpy, importlib-metadata, httpcore, dataclasses, commonmark, colorama, certifi, ruamel-yaml, rich, python-libsbml-experimental, pydantic, pandas, optlang, importlib-resources, httpx, future, diskcache, depinfo, appdirs, cobra
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.0.1 requires pyqt5<5.13; python_version >= "3", which is not installed.
# spyder 4.0.1 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# spyder 4.0.1 requires jedi==0.14.1, but you have jedi 0.17.2 which is incompatible.
# escher 1.7.3 requires pytest<5,>=4.0.1, but you have pytest 5.3.5 which is incompatible.
# cameo 0.13.0 requires optlang==1.4.2, but you have optlang 1.4.4 which is incompatible.
# awscli 1.18.197 requires colorama<0.4.4,>=0.2.5; python_version != "3.4", but you have colorama 0.4.4 which is incompatible.
# astroid 2.4.2 requires lazy-object-proxy==1.4.*, but you have lazy-object-proxy 1.5.2 which is incompatible.
# Successfully installed appdirs-1.4.4 certifi-2020.12.5 cobra-0.20.0 colorama-0.4.4 commonmark-0.9.1 contextvars-2.4 dataclasses-0.7 depinfo-1.6.0 diskcache-5.1.0 future-0.18.2 h11-0.11.0 httpcore-0.12.2 httpx-0.16.1 idna-2.10 immutables-0.14 importlib-metadata-3.3.0 importlib-resources-3.3.0 mpmath-1.1.0 numpy-1.19.4 optlang-1.4.4 pandas-1.1.5 pydantic-1.7.3 pygments-2.7.3 python-dateutil-2.8.1 python-libsbml-experimental-5.18.3 pytz-2020.4 rfc3986-1.4.0 rich-6.2.0 ruamel-yaml-0.15.87 ruamel.yaml.clib-0.2.2 six-1.15.0 sniffio-1.2.0 swiglpk-4.65.1 sympy-1.7.1 typing-extensions-3.7.4.3 zipp-3.4.0
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install cameo --ignore-installed ruamel-yaml
# Out:
# Collecting cameo
#   Using cached cameo-0.13.0-py2.py3-none-any.whl (13.8 MB)
# Collecting ruamel-yaml
#   Using cached ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting blessings>=1.5.1
#   Using cached blessings-1.7-py3-none-any.whl (18 kB)
# Collecting click>=6.7
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 1.9 MB/s eta 0:00:011
# Collecting cobra>=0.11.1
#   Using cached cobra-0.20.0-py2.py3-none-any.whl (2.4 MB)
# Collecting appdirs~=1.4
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting depinfo
#   Using cached depinfo-1.6.0-py2.py3-none-any.whl (8.6 kB)
# Collecting diskcache~=5.0
#   Using cached diskcache-5.1.0-py3-none-any.whl (44 kB)
# Collecting escher>=1.1.2
#   Using cached Escher-1.7.3-py3-none-any.whl (1.2 MB)
# Collecting future>=0.15.2
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 22.9 MB/s eta 0:00:01
# Collecting gnomic==1.0.1
#   Using cached gnomic-1.0.1-py3-none-any.whl
# Collecting grako==3.18.1
#   Using cached grako-3.18.1-py2.py3-none-any.whl (76 kB)
# Collecting httpx~=0.14
#   Using cached httpx-0.16.1-py3-none-any.whl (65 kB)
# Collecting certifi
#   Downloading certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 39.7 MB/s eta 0:00:01
# Collecting httpcore==0.12.*
#   Using cached httpcore-0.12.2-py3-none-any.whl (54 kB)
# Collecting h11==0.*
#   Using cached h11-0.11.0-py2.py3-none-any.whl (54 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-3.3.0-py3-none-any.whl (10 kB)
# Collecting importlib-resources
#   Using cached importlib_resources-3.3.0-py2.py3-none-any.whl (26 kB)
# Collecting inspyred>=1.0
#   Using cached inspyred-1.0.1-py2.py3-none-any.whl (88 kB)
# Collecting IProgress>=0.4
#   Using cached IProgress-0.4-py3-none-any.whl (11 kB)
# Collecting ipywidgets<8,>=7.4.0
#   Downloading ipywidgets-7.5.1-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 30.8 MB/s eta 0:00:01
# Collecting ipykernel>=4.5.1
#   Downloading ipykernel-5.4.2-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 31.1 MB/s eta 0:00:01
# Collecting ipython>=4.0.0
#   Downloading ipython-7.16.1-py3-none-any.whl (785 kB)
#      |████████████████████████████████| 785 kB 36.5 MB/s eta 0:00:01
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting decorator
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting jedi>=0.10
#   Downloading jedi-0.17.2-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 40.5 MB/s eta 0:00:01
# Collecting Jinja2<3,>=2.7.3
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 60.2 MB/s eta 0:00:01
# Collecting jsonschema<4,>=3.0.1
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 766 kB/s s eta 0:00:01
# Collecting attrs>=17.4.0
#   Downloading attrs-20.3.0-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 12.1 MB/s eta 0:00:01
# Collecting jupyter-client
#   Downloading jupyter_client-6.1.7-py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 90.1 MB/s eta 0:00:01
# Collecting jupyter-core>=4.6.0
#   Downloading jupyter_core-4.7.0-py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 1.9 MB/s  eta 0:00:01
# Collecting lazy-object-proxy>=1.2.0
#   Downloading lazy_object_proxy-1.5.2-cp36-cp36m-manylinux1_x86_64.whl (51 kB)
#      |████████████████████████████████| 51 kB 1.1 MB/s  eta 0:00:01
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting nbformat>=4.2.0
#   Downloading nbformat-5.0.8-py3-none-any.whl (172 kB)
#      |████████████████████████████████| 172 kB 89.8 MB/s eta 0:00:01
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting networkx>=2.4
#   Downloading networkx-2.5-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 29.7 MB/s eta 0:00:01
# Collecting numexpr>=2.4
#   Downloading numexpr-2.7.1-cp36-cp36m-manylinux1_x86_64.whl (162 kB)
#      |████████████████████████████████| 162 kB 106.5 MB/s eta 0:00:01
# Collecting numpy>=1.9.1
#   Downloading numpy-1.19.4-cp36-cp36m-manylinux2010_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 73.1 MB/s eta 0:00:01
# Collecting openpyxl>=2.4.5
#   Downloading openpyxl-3.0.5-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 105.4 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.0.1.tar.gz (8.4 kB)
# Collecting jdcal
#   Downloading jdcal-1.4.1-py2.py3-none-any.whl (9.5 kB)
# Collecting optlang==1.4.2
#   Using cached optlang-1.4.2-py2.py3-none-any.whl (121 kB)
# Collecting ordered-set>=1.2
#   Using cached ordered_set-4.0.2-py2.py3-none-any.whl
# Collecting palettable>=2.1.1
#   Using cached palettable-3.3.0-py2.py3-none-any.whl (111 kB)
# Collecting pandas>=1.1.3
#   Using cached pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting parso<0.8.0,>=0.7.0
#   Downloading parso-0.7.1-py2.py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 99.8 MB/s eta 0:00:01
# Collecting pexpect
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 14.0 MB/s eta 0:00:01
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.8-py3-none-any.whl (355 kB)
#      |████████████████████████████████| 355 kB 87.7 MB/s eta 0:00:01
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.6.0-py2.py3-none-any.whl (39 kB)
# Collecting pydantic~=1.6
#   Using cached pydantic-1.7.3-cp36-cp36m-manylinux2014_x86_64.whl (9.2 MB)
# Collecting dataclasses>=0.6
#   Using cached dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting pygments
#   Using cached Pygments-2.7.3-py3-none-any.whl (950 kB)
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.17.3.tar.gz (106 kB)
#      |████████████████████████████████| 106 kB 118.5 MB/s eta 0:00:01
# Collecting pytest<5,>=4.0.1
#   Using cached pytest-4.6.11-py2.py3-none-any.whl (231 kB)
# Collecting atomicwrites>=1.0
#   Downloading atomicwrites-1.4.0-py2.py3-none-any.whl (6.8 kB)
# Collecting more-itertools>=4.0.0
#   Downloading more_itertools-8.6.0-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 7.5 MB/s  eta 0:00:01
# Collecting packaging
#   Downloading packaging-20.8-py2.py3-none-any.whl (39 kB)
# Collecting pluggy<1.0,>=0.12
#   Downloading pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Collecting py>=1.5.0
#   Downloading py-1.10.0-py2.py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 15.6 MB/s  eta 0:00:01
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 13.7 MB/s  eta 0:00:01
# Collecting python-dateutil>=2.1
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 100.6 MB/s eta 0:00:01
# Collecting python-libsbml-experimental==5.18.3
#   Using cached python_libsbml_experimental-5.18.3-cp36-cp36m-manylinux1_x86_64.whl (7.6 MB)
# Collecting pytz>=2017.2
#   Downloading pytz-2020.4-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 81.5 MB/s eta 0:00:01
# Collecting pyzmq>=13
#   Downloading pyzmq-20.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 95.9 MB/s eta 0:00:01
# Collecting requests>=2.10.0
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 16.9 MB/s  eta 0:00:01
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 103.5 MB/s eta 0:00:01
# Collecting idna<3,>=2.5
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Using cached rfc3986-1.4.0-py2.py3-none-any.whl (31 kB)
# Collecting rich~=6.0
#   Using cached rich-6.2.0-py3-none-any.whl (150 kB)
# Collecting colorama<0.5.0,>=0.4.0
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting commonmark<0.10.0,>=0.9.0
#   Using cached commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Collecting dataclasses>=0.6
#   Using cached dataclasses-0.7-py3-none-any.whl (18 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Using cached ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting scipy>=0.14.0
#   Downloading scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 90.3 MB/s eta 0:00:01
# Collecting setuptools>=18.5
#   Downloading setuptools-51.0.0-py3-none-any.whl (785 kB)
#      |████████████████████████████████| 785 kB 94.1 MB/s eta 0:00:01
# Collecting six
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting sniffio
#   Using cached sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting contextvars>=2.1
#   Using cached contextvars-2.4-py3-none-any.whl
# Collecting immutables>=0.9
#   Using cached immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98 kB)
# Collecting swiglpk
#   Using cached swiglpk-4.65.1-cp36-cp36m-manylinux1_x86_64.whl (627 kB)
# Collecting sympy>=1.0.0
#   Downloading sympy-1.7.1-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 78.0 MB/s eta 0:00:01
# Collecting mpmath>=0.19
#   Downloading mpmath-1.1.0.tar.gz (512 kB)
#      |████████████████████████████████| 512 kB 80.9 MB/s eta 0:00:01
# Collecting tornado>=4.2
#   Downloading tornado-6.1-cp36-cp36m-manylinux2010_x86_64.whl (427 kB)
#      |████████████████████████████████| 427 kB 74.2 MB/s eta 0:00:01
# Collecting traitlets>=4.3.1
#   Downloading traitlets-4.3.3-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 9.9 MB/s s eta 0:00:01
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.2-py2.py3-none-any.whl (136 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 77.3 MB/s eta 0:00:01
# Collecting notebook>=4.4.1
#   Downloading notebook-6.1.5-py3-none-any.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 81.8 MB/s eta 0:00:01
# Collecting argon2-cffi
#   Downloading argon2_cffi-20.1.0-cp35-abi3-manylinux1_x86_64.whl (97 kB)
#      |████████████████████████████████| 97 kB 1.5 MB/s s eta 0:00:01
# Collecting cffi>=1.0.0
#   Downloading cffi-1.14.4-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
#      |████████████████████████████████| 401 kB 111.8 MB/s eta 0:00:01
# Collecting nbconvert
#   Downloading nbconvert-6.0.7-py3-none-any.whl (552 kB)
#      |████████████████████████████████| 552 kB 114.0 MB/s eta 0:00:01
# Collecting bleach
#   Downloading bleach-3.2.1-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 108.5 MB/s eta 0:00:01
# Collecting defusedxml
#   Downloading defusedxml-0.6.0-py2.py3-none-any.whl (23 kB)
# Collecting entrypoints>=0.2.2
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting mistune<2,>=0.8.1
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting nbclient<0.6.0,>=0.5.0
#   Downloading nbclient-0.5.1-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 8.5 MB/s s eta 0:00:01
# Collecting async-generator
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.4.3-py3-none-any.whl (5.3 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.4.3.tar.gz (16 kB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 4.3 MB/s  eta 0:00:01
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 105.7 MB/s eta 0:00:01
# Collecting Send2Trash
#   Downloading Send2Trash-1.5.0-py3-none-any.whl (12 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.9.1-py3-none-any.whl (13 kB)
# Collecting testpath
#   Downloading testpath-0.4.4-py2.py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 108.6 MB/s eta 0:00:01
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Building wheels for collected packages: future, et-xmlfile, pyrsistent, mpmath, pandocfilters
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491058 sha256=d5093a1e8e079ae000ec806fd16095855a5e05194277491ed53ae5f69b1d7e07
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/6e/9c/ed/4499c9865ac1002697793e0ae05ba6be33553d098f3347fb94
#   Building wheel for et-xmlfile (setup.py) ... done
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8915 sha256=e92d1cebbcde58cd22f3fae32ae07f1fda193a84d1b7ee0ca9495e9f354bc25e
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/ef/92/e0/956c00decf3091294b8800d9104f6169a1adacfaafd122ed42
#   Building wheel for pyrsistent (setup.py) ... done
#   Created wheel for pyrsistent: filename=pyrsistent-0.17.3-cp36-cp36m-linux_x86_64.whl size=113927 sha256=6bd000c816827ee727adf6c03d6793eea1d9baf2de21be083dfe3b2867367a54
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/34/13/19/294da8e11bce7e563afee51251b9fa878185e14f4b5caf00cb
#   Building wheel for mpmath (setup.py) ... done
#   Created wheel for mpmath: filename=mpmath-1.1.0-py3-none-any.whl size=532239 sha256=0f1be66556f8e292aa645b7d6eb4cb4506d0947b423e669e074a3f01b4b23556
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/e8/38/69/aa17553ad31f09ff5fa44c8a1a6c5b47e7c9261e9c7c16b9fb
#   Building wheel for pandocfilters (setup.py) ... done
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.3-py3-none-any.whl size=7991 sha256=336169ec949aaed75002ec06b3e9792607dbb34a7634a045f21685e5c6336db1
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/12/12/89/fe63ac4d6ee6440daab4db77b78c63f7f192b700f844b6639f
# Successfully built future et-xmlfile pyrsistent mpmath pandocfilters
# Installing collected packages: zipp, typing-extensions, six, ipython-genutils, decorator, traitlets, setuptools, pyrsistent, importlib-metadata, attrs, wcwidth, tornado, pyzmq, python-dateutil, pyparsing, ptyprocess, parso, jupyter-core, jsonschema, webencodings, pygments, pycparser, prompt-toolkit, pickleshare, pexpect, packaging, nest-asyncio, nbformat, MarkupSafe, jupyter-client, jedi, immutables, backcall, async-generator, testpath, pandocfilters, nbclient, mistune, jupyterlab-pygments, Jinja2, ipython, entrypoints, defusedxml, contextvars, cffi, bleach, terminado, sniffio, Send2Trash, rfc3986, prometheus-client, nbconvert, mpmath, ipykernel, idna, h11, argon2-cffi, sympy, swiglpk, ruamel.yaml.clib, pytz, numpy, notebook, httpcore, dataclasses, commonmark, colorama, certifi, widgetsnbextension, ruamel-yaml, rich, python-libsbml-experimental, pydantic, py, pluggy, pandas, optlang, more-itertools, importlib-resources, httpx, future, diskcache, depinfo, atomicwrites, appdirs, urllib3, pytest, jdcal, ipywidgets, grako, et-xmlfile, cobra, chardet, scipy, requests, palettable, ordered-set, openpyxl, numexpr, networkx, lazy-object-proxy, IProgress, inspyred, gnomic, escher, click, blessings, cameo
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.0.1 requires pyqt5<5.13; python_version >= "3", which is not installed.
# spyder 4.0.1 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# spyder 4.0.1 requires jedi==0.14.1, but you have jedi 0.17.2 which is incompatible.
# python-language-server 0.31.7 requires jedi<0.16,>=0.14.1, but you have jedi 0.17.2 which is incompatible.
# awscli 1.18.197 requires colorama<0.4.4,>=0.2.5; python_version != "3.4", but you have colorama 0.4.4 which is incompatible.
# astroid 2.4.2 requires lazy-object-proxy==1.4.*, but you have lazy-object-proxy 1.5.2 which is incompatible.
# Successfully installed IProgress-0.4 Jinja2-2.11.2 MarkupSafe-1.1.1 Send2Trash-1.5.0 appdirs-1.4.4 argon2-cffi-20.1.0 async-generator-1.10 atomicwrites-1.4.0 attrs-20.3.0 backcall-0.2.0 bleach-3.2.1 blessings-1.7 cameo-0.13.0 certifi-2020.12.5 cffi-1.14.4 chardet-4.0.0 click-7.1.2 cobra-0.20.0 colorama-0.4.4 commonmark-0.9.1 contextvars-2.4 dataclasses-0.7 decorator-4.4.2 defusedxml-0.6.0 depinfo-1.6.0 diskcache-5.1.0 entrypoints-0.3 escher-1.7.3 et-xmlfile-1.0.1 future-0.18.2 gnomic-1.0.1 grako-3.18.1 h11-0.11.0 httpcore-0.12.2 httpx-0.16.1 idna-2.10 immutables-0.14 importlib-metadata-3.3.0 importlib-resources-3.3.0 inspyred-1.0.1 ipykernel-5.4.2 ipython-7.16.1 ipython-genutils-0.2.0 ipywidgets-7.5.1 jdcal-1.4.1 jedi-0.17.2 jsonschema-3.2.0 jupyter-client-6.1.7 jupyter-core-4.7.0 jupyterlab-pygments-0.1.2 lazy-object-proxy-1.5.2 mistune-0.8.4 more-itertools-8.6.0 mpmath-1.1.0 nbclient-0.5.1 nbconvert-6.0.7 nbformat-5.0.8 nest-asyncio-1.4.3 networkx-2.5 notebook-6.1.5 numexpr-2.7.1 numpy-1.19.4 openpyxl-3.0.5 optlang-1.4.2 ordered-set-4.0.2 packaging-20.8 palettable-3.3.0 pandas-1.1.5 pandocfilters-1.4.3 parso-0.7.1 pexpect-4.8.0 pickleshare-0.7.5 pluggy-0.13.1 prometheus-client-0.9.0 prompt-toolkit-3.0.8 ptyprocess-0.6.0 py-1.10.0 pycparser-2.20 pydantic-1.7.3 pygments-2.7.3 pyparsing-2.4.7 pyrsistent-0.17.3 pytest-5.3.5 python-dateutil-2.8.1 python-libsbml-experimental-5.18.3 pytz-2020.4 pyzmq-20.0.0 requests-2.25.1 rfc3986-1.4.0 rich-6.2.0 ruamel-yaml-0.15.87 ruamel.yaml.clib-0.2.2 scipy-1.5.4 setuptools-51.0.0 six-1.15.0 sniffio-1.2.0 swiglpk-4.65.1 sympy-1.7.1 terminado-0.9.1 testpath-0.4.4 tornado-6.1 traitlets-4.3.3 typing-extensions-3.7.4.3 urllib3-1.26.2 wcwidth-0.2.5 webencodings-0.5.1 widgetsnbextension-3.5.1 zipp-3.4.0
# WARNING: You are using pip version 20.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/amazonei_mxnet_p36/bin/python -m pip install --upgrade pip' command.

# %%
from cameo import models
import cobra as cb
from cameo import load_model

# %%
from cameo import load_model
model = load_model('Chlorella_v.xml')

# %%
#Here, we get the flux through the biomass reaction in Ecoli

with model:
    model.reactions.EX_o2_e.lower_bound = 0
    model.reactions.EX_co2.lower_bound = 0
    model.reactions.EX_glc__D_e.lower_bound = -10
    model.objective = 'BIOMASS_Ec_iAF1260_core_59p81M'
    print("Max Ethanol production rate: ",fba(model).fluxes['EX_etoh_e'])
    print("Glucose uptake rate:", fba(model).fluxes['EX_glc__D_e'])
    print("Growth Rate(Biomass core production rate):",fba(model).fluxes['BIOMASS_Ec_iAF1260_core_59p81M'])
fba_result = fba(model)
print(fba_result.fluxes['BIOMASS_Ec_iAF1260_core_59p81M'])
print(fba_result.fluxes['EX_etoh_e'])
print(fba_result.fluxes['EX_o2_e'])
print(fba_result.fluxes['EX_co2_e'])
print("Glucose uptake rate:", fba(model).fluxes['EX_glc__D_e'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/cobra/core/dictlist.py in __getattr__(self, attr)
#     454         try:
# --> 455             return DictList.get_by_id(self, attr)
#     456         except KeyError:
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/cobra/core/dictlist.py in get_by_id(self, id)
#      57         """return the element with a matching id"""
# ---> 58         return list.__getitem__(self, self._dict[id])
#      59
#
# KeyError: 'EX_o2_e'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-5abd37d2c2ec> in <module>
#       2
#       3 with model:
# ----> 4     model.reactions.EX_o2_e.lower_bound = 0
#       5     model.reactions.EX_co2.lower_bound = 0
#       6     model.reactions.EX_glc__D_e.lower_bound = -10
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/cobra/core/dictlist.py in __getattr__(self, attr)
#     455             return DictList.get_by_id(self, attr)
#     456         except KeyError:
# --> 457             raise AttributeError("DictList has no attribute or entry %s" % attr)
#     458
#     459     def __dir__(self):
#
# AttributeError: DictList has no attribute or entry EX_o2_e

# %%
display(fba_result.data_frame)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             self.info(buf=buf)
#     733             return buf.getvalue()
# --> 734
#     735         max_rows = get_option("display.max_rows")
#     736         min_rows = get_option("display.min_rows")
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     982             A ``border=border`` attribute is included in the opening
#     983             ``<table>`` tag. Default ``pd.options.display.html.border``.
# --> 984         """
#     985         from pandas.io.formats.html import HTMLFormatter, NotebookFormatter
#     986
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/io/formats/html.py in __init__(self, formatter, classes, border)
#      57         self.col_space = {
#      58             column: f"{value}px" if isinstance(value, int) else value
# ---> 59             for column, value in self.fmt.col_space.items()
#      60         }
#      61
#
# AttributeError: 'NoneType' object has no attribute 'items'
#                       flux
# rxn00001_c0    -411.981507
# rxn00001_d0       0.000000
# rxn00001_g0       0.000000
# rxn00001_v0       0.000000
# rxn00001_w0       0.000000
# ...                    ...
# EX_cpd00205_e0  -25.872997
# EX_cpd00007_e0 -194.961138
# EX_cpd00009_e0  -29.631576
# DM_cpd02701_c0    0.008428
# DM_cpd11416_c0   84.276862
#
# [1085 rows x 1 columns]

# %%
from cameo import fba
fba_result = fba(model)
fba_result.data_frame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             self.info(buf=buf)
#     733             return buf.getvalue()
# --> 734
#     735         max_rows = get_option("display.max_rows")
#     736         min_rows = get_option("display.min_rows")
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     982             A ``border=border`` attribute is included in the opening
#     983             ``<table>`` tag. Default ``pd.options.display.html.border``.
# --> 984         """
#     985         from pandas.io.formats.html import HTMLFormatter, NotebookFormatter
#     986
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/io/formats/html.py in __init__(self, formatter, classes, border)
#      57         self.col_space = {
#      58             column: f"{value}px" if isinstance(value, int) else value
# ---> 59             for column, value in self.fmt.col_space.items()
#      60         }
#      61
#
# AttributeError: 'NoneType' object has no attribute 'items'
#                       flux
# rxn00001_c0    -411.981507
# rxn00001_d0       0.000000
# rxn00001_g0       0.000000
# rxn00001_v0       0.000000
# rxn00001_w0       0.000000
# ...                    ...
# EX_cpd00205_e0  -25.872997
# EX_cpd00007_e0 -194.961138
# EX_cpd00009_e0  -29.631576
# DM_cpd02701_c0    0.008428
# DM_cpd11416_c0   84.276862
#
# [1085 rows x 1 columns]

# %%
deletion_result = cobra.flux_analysis.single_reaction_deletion(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-f355e312f23d> in <module>
# ----> 1 deletion_result = cobra.flux_analysis.single_reaction_deletion(model)
#
# NameError: name 'cobra' is not defined

# %%
#E_coli model
ec_model = models.bigg.iML1515
#Saccharomyces cerevisiae S288C model
sc_model= models.bigg.iMM904

# %%
from cameo import fba
fba_result = fba(ec_model)
fba_result.data_frame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/core/frame.py in _repr_html_(self)
#     732             self.info(buf=buf)
#     733             return buf.getvalue()
# --> 734
#     735         max_rows = get_option("display.max_rows")
#     736         min_rows = get_option("display.min_rows")
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/io/formats/format.py in to_html(self, buf, encoding, classes, notebook, border)
#     982             A ``border=border`` attribute is included in the opening
#     983             ``<table>`` tag. Default ``pd.options.display.html.border``.
# --> 984         """
#     985         from pandas.io.formats.html import HTMLFormatter, NotebookFormatter
#     986
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/io/formats/html.py in __init__(self, formatter, classes, border)
#      57         self.col_space = {
#      58             column: f"{value}px" if isinstance(value, int) else value
# ---> 59             for column, value in self.fmt.col_space.items()
#      60         }
#      61
#
# AttributeError: 'NoneType' object has no attribute 'items'
#              flux
# CYTDK2   0.000000
# XPPT     0.000000
# HXPRT    0.000000
# NDPK5    0.000000
# SHK3Dr   0.313203
# ...           ...
# MPTS     0.000000
# MOCOS    0.000000
# BMOGDS2  0.000000
# FESD2s   0.000000
# OCTNLL   0.000000
#
# [2712 rows x 1 columns]

# %%
#Performing Phenotypic Phase plane flux modelling for various input parameters in E_coli
#Ethanol Exchange
import matplotlib.pyplot as plt
from cameo import phenotypic_phase_plane
ec_model.reactions.EX_o2_e.lower_bound = -20
ec_model.reactions.EX_co2_e.lower_bound = 0

result = phenotypic_phase_plane(ec_model,variables=[ec_model.reactions.BIOMASS_Ec_iML1515_core_75p37M],
                                      objective=ec_model.reactions.EX_etoh_e,points=10)
plt.plot(result)
result.data_frame
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/matplotlib/units.py in get_converter(self, x)
#     154         try:  # Look up in the cache.
# --> 155             return self[type(x)]
#     156         except KeyError:
#
# KeyError: <class 'numpy.ndarray'>
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/matplotlib/units.py in get_converter(self, x)
#     154         try:  # Look up in the cache.
# --> 155             return self[type(x)]
#     156         except KeyError:
#
# KeyError: <class 'cameo.flux_analysis.analysis.PhenotypicPhasePlaneResult'>
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645
# -> 2646         Examples
#    2647         --------
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-b19299635407> in <module>
#       8 result = phenotypic_phase_plane(ec_model,variables=[ec_model.reactions.BIOMASS_Ec_iML1515_core_75p37M],
#       9                                       objective=ec_model.reactions.EX_etoh_e,points=10)
# ---> 10 plt.plot(result)
#      11 result.data_frame
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     242         if self.axes.xaxis is not None and self.axes.yaxis is not None:
#     243             bx = self.axes.xaxis.update_units(x)
# --> 244             by = self.axes.yaxis.update_units(y)
#     245
#     246             if self.command != 'plot':
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/matplotlib/axis.py in update_units(self, data)
#    1485         """
#    1486
# -> 1487         converter = munits.registry.get_converter(data)
#    1488         if converter is None:
#    1489             return False
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/matplotlib/units.py in get_converter(self, x)
#     163                 # where indexing returns instances of the same iterable class.
#     164                 if type(first) is not type(x):
# --> 165                     return self.get_converter(first)
#     166         return None
#     167
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/matplotlib/units.py in get_converter(self, x)
#     156         except KeyError:
#     157             try:  # If cache lookup fails, look up based on first element...
# --> 158                 first = cbook.safe_first_element(x)
#     159             except (TypeError, StopIteration):
#     160                 pass
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in safe_first_element(obj)
#    1691         raise RuntimeError("matplotlib does not support generators "
#    1692                            "as input")
# -> 1693     return next(iter(obj))
#    1694
#    1695
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/cameo/flux_analysis/analysis.py in __getitem__(self, item)
#     854
#     855     def __getitem__(self, item):
# --> 856         return self._phase_plane[item]
#     857
#     858     def iterrows(self):
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798
#    2799         else:
# -> 2800             new_values = self.values.T
#    2801             if copy:
#    2802                 new_values = new_values.copy()
#
# ~/anaconda3/envs/amazonei_mxnet_p36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646         Examples
#    2647         --------
# -> 2648         >>> idx1 = pd.Index([1, 2, 3, 4])
#    2649         >>> idx2 = pd.Index([3, 4, 5, 6])
#    2650         >>> idx1.intersection(idx2)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
